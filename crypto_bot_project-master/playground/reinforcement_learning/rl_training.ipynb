# %%
from name_me.data_handling import dataprovider as dp
from name_me.data_handling import data_lambdas as dls
from name_me.data_handling import schemes

from name_me.profiles import profile_manager as pm

from name_me.reinforcement_learning import agents
from name_me.reinforcement_learning import envir as rl_env
from name_me.reinforcement_learning import exploration_processes as exp_p

# %%
profile = pm.get_profile_by_file('../profile_files/rl_training.json')

data_lambda = dls.DataLambda.get_test_lambda(
    profile=profile
)
transformer = schemes.get_transformer(
    uuid=profile["transformer_uuid"]
)

provider = dp.DataProvider(
    data_lambda=data_lambda,
    transformer=transformer
)

envir = rl_env.TradingEnvir(
    provider=provider,
    profile=profile
)

process = exp_p.EpsilonGreedyProcess(
    action_space=envir.action_space,
    profile=profile
)

agent = agents.DuellingAgent(
    env=envir,
    process=process,
    profile=profile
)

# %%
rewards, cum_rewards = agent.train(500)
# Out:
# EPISODE: 1/500
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 1
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 2
# r      : 0.998584 😰
# reward : -0.001417 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 3
# r      : 0.994650 😰
# reward : -0.005364 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 4
# r      : 0.997738 😰
# reward : -0.002265 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 5
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 6
# r      : 0.968099 😰
# reward : -0.032420 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 7
# r      : 0.964496 😰
# reward : -0.036149 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 8
# r      : 0.997667 😰
# reward : -0.002336 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 9
# r      : 1.035329 👍
# reward : 0.034719 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 10
# r      : 1.033618 👍
# reward : 0.033066 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 11
# r      : 0.968461 😰
# reward : -0.032047 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 12
# r      : 1.013513 👍
# reward : 0.013422 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 13
# r      : 0.987117 😰
# reward : -0.012966 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 14
# r      : 0.993955 😰
# reward : -0.006063 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 15
# r      : 1.005314 👍
# reward : 0.005300 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 16
# r      : 0.997762 😰
# reward : -0.002241 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 17
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 18
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 19
# r      : 1.013820 👍
# reward : 0.013725 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 20
# r      : 1.009933 👍
# reward : 0.009884 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 21
# r      : 1.001996 👍
# reward : 0.001994 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 22
# r      : 1.001838 👍
# reward : 0.001836 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 23
# r      : 1.014109 👍
# reward : 0.014011 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 24
# r      : 0.997781 😰
# reward : -0.002221 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 25
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 26
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 27
# r      : 0.978884 😰
# reward : -0.021342 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 28
# r      : 1.007661 👍
# reward : 0.007632 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 29
# r      : 1.003810 👍
# reward : 0.003803 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 30
# r      : 0.994597 😰
# reward : -0.005417 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 31
# r      : 0.997738 😰
# reward : -0.002265 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 32
# r      : 1.019289 👍
# reward : 0.019106 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 33
# r      : 0.997793 😰
# reward : -0.002210 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 34
# r      : 0.969127 😰
# reward : -0.031360 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 35
# r      : 0.972849 😰
# reward : -0.027526 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 36
# r      : 1.017514 👍
# reward : 0.017362 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 37
# r      : 1.014604 👍
# reward : 0.014498 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 38
# r      : 0.997782 😰
# reward : -0.002220 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 39
# r      : 0.994285 😰
# reward : -0.005731 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 40
# r      : 0.997737 😰
# reward : -0.002265 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 41
# r      : 1.014343 👍
# reward : 0.014241 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 42
# r      : 0.997782 😰
# reward : -0.002221 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 43
# r      : 1.014980 👍
# reward : 0.014869 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 44
# r      : 1.012300 👍
# reward : 0.012224 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 45
# r      : 0.997777 😰
# reward : -0.002225 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 46
# r      : 1.002270 👍
# reward : 0.002268 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 47
# r      : 0.980849 😰
# reward : -0.019337 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Long as step 48
# r      : 0.976067 😰
# reward : -0.024224 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : Short as step 49
# r      : 1.026458 👍
# reward : 0.026114 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 50
# r      : 0.997808 😰
# reward : -0.002194 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 1.000.
#
# ACTION : None as step 51
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 52
# r      : 0.964603 😰
# reward : -0.036039 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 53
# r      : 0.973560 😰
# reward : -0.026796 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 54
# r      : 0.983179 😰
# reward : -0.016964 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 55
# r      : 0.994320 😰
# reward : -0.005696 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 56
# r      : 0.989869 😰
# reward : -0.010182 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 57
# r      : 0.984906 😰
# reward : -0.015209 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 58
# r      : 0.978361 😰
# reward : -0.021876 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 59
# r      : 0.975546 😰
# reward : -0.024758 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 60
# r      : 0.976695 😰
# reward : -0.023580 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 61
# r      : 0.981461 😰
# reward : -0.018713 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 62
# r      : 1.006205 👍
# reward : 0.006186 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 63
# r      : 0.993771 😰
# reward : -0.006248 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 64
# r      : 1.007768 👍
# reward : 0.007738 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 65
# r      : 0.979022 😰
# reward : -0.021201 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 66
# r      : 0.977140 😰
# reward : -0.023125 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 67
# r      : 0.997697 😰
# reward : -0.002305 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 68
# r      : 1.022945 👍
# reward : 0.022685 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 69
# r      : 0.997800 😰
# reward : -0.002202 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 70
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 71
# r      : 0.994385 😰
# reward : -0.005631 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 72
# r      : 1.007383 👍
# reward : 0.007356 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 73
# r      : 0.997766 😰
# reward : -0.002236 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 74
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 75
# r      : 1.026819 👍
# reward : 0.026466 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 76
# r      : 0.966253 😰
# reward : -0.034330 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 77
# r      : 0.974635 😰
# reward : -0.025692 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 78
# r      : 0.997691 😰
# reward : -0.002311 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 79
# r      : 1.005212 👍
# reward : 0.005199 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 80
# r      : 0.999275 😰
# reward : -0.000726 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 81
# r      : 0.980176 😰
# reward : -0.020023 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 82
# r      : 0.997704 😰
# reward : -0.002298 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 83
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 84
# r      : 0.961188 😰
# reward : -0.039586 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 85
# r      : 0.997659 😰
# reward : -0.002344 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 86
# r      : 1.029635 👍
# reward : 0.029204 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 87
# r      : 1.024003 👍
# reward : 0.023719 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 88
# r      : 0.981525 😰
# reward : -0.018648 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 89
# r      : 0.997708 😰
# reward : -0.002295 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 90
# r      : 0.990226 😰
# reward : -0.009822 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 91
# r      : 0.984600 😰
# reward : -0.015520 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 92
# r      : 0.997715 😰
# reward : -0.002288 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 93
# r      : 1.017335 👍
# reward : 0.017186 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 94
# r      : 0.997788 😰
# reward : -0.002214 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 95
# r      : 0.989445 😰
# reward : -0.010611 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 96
# r      : 0.993672 😰
# reward : -0.006348 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 97
# r      : 0.987135 😰
# reward : -0.012949 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 98
# r      : 1.018875 👍
# reward : 0.018699 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 99
# r      : 0.962915 😰
# reward : -0.037790 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 100
# r      : 1.033949 👍
# reward : 0.033385 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 101
# r      : 0.997824 😰
# reward : -0.002178 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 102
# r      : 0.958848 😰
# reward : -0.042023 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 103
# r      : 0.997653 😰
# reward : -0.002349 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 104
# r      : 1.020539 👍
# reward : 0.020331 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 105
# r      : 1.010992 👍
# reward : 0.010932 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 106
# r      : 0.996382 😰
# reward : -0.003624 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 107
# r      : 0.997742 😰
# reward : -0.002261 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 108
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 109
# r      : 1.019852 👍
# reward : 0.019657 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 110
# r      : 0.974662 😰
# reward : -0.025665 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 111
# r      : 0.997692 😰
# reward : -0.002311 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 112
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 113
# r      : 0.991570 😰
# reward : -0.008466 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 114
# r      : 1.014064 👍
# reward : 0.013966 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 115
# r      : 1.030473 👍
# reward : 0.030018 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 116
# r      : 1.040199 👍
# reward : 0.039412 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 117
# r      : 0.948822 😰
# reward : -0.052534 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 118
# r      : 1.043880 👍
# reward : 0.042944 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 119
# r      : 1.045506 👍
# reward : 0.044501 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 120
# r      : 1.037986 👍
# reward : 0.037282 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 121
# r      : 0.997832 😰
# reward : -0.002170 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 122
# r      : 1.011212 👍
# reward : 0.011149 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 123
# r      : 0.995483 😰
# reward : -0.004527 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 124
# r      : 0.997740 😰
# reward : -0.002263 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 125
# r      : 0.977516 😰
# reward : -0.022741 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 126
# r      : 0.976034 😰
# reward : -0.024258 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 127
# r      : 1.017903 👍
# reward : 0.017745 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 128
# r      : 1.016593 👍
# reward : 0.016457 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 129
# r      : 1.007198 👍
# reward : 0.007172 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 130
# r      : 0.999676 😰
# reward : -0.000324 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 131
# r      : 1.016322 👍
# reward : 0.016190 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 132
# r      : 1.027384 👍
# reward : 0.027016 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 133
# r      : 1.035859 👍
# reward : 0.035231 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 134
# r      : 0.997828 😰
# reward : -0.002174 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 135
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 136
# r      : 1.033260 👍
# reward : 0.032719 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 137
# r      : 1.025999 👍
# reward : 0.025667 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 138
# r      : 1.013345 👍
# reward : 0.013256 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 139
# r      : 0.997780 😰
# reward : -0.002223 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 140
# r      : 0.983716 😰
# reward : -0.016418 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 141
# r      : 1.019896 👍
# reward : 0.019701 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 142
# r      : 0.964683 😰
# reward : -0.035955 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 143
# r      : 0.968025 😰
# reward : -0.032498 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 144
# r      : 0.972271 😰
# reward : -0.028120 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 145
# r      : 0.997686 😰
# reward : -0.002317 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 146
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 147
# r      : 1.005494 👍
# reward : 0.005479 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 148
# r      : 1.022214 👍
# reward : 0.021971 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Long as step 149
# r      : 0.960074 😰
# reward : -0.040745 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : None as step 150
# r      : 0.997656 😰
# reward : -0.002346 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.999.
#
# ACTION : Short as step 151
# r      : 1.049035 👍
# reward : 0.047871 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 152
# r      : 0.997855 😰
# reward : -0.002147 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 153
# r      : 0.949760 😰
# reward : -0.051546 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 154
# r      : 0.960945 😰
# reward : -0.039838 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 155
# r      : 1.021691 👍
# reward : 0.021459 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 156
# r      : 1.012261 👍
# reward : 0.012186 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 157
# r      : 0.997777 😰
# reward : -0.002225 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 158
# r      : 1.008940 👍
# reward : 0.008900 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 159
# r      : 0.997770 😰
# reward : -0.002233 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 160
# r      : 0.979749 😰
# reward : -0.020458 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 161
# r      : 0.986647 😰
# reward : -0.013443 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 162
# r      : 0.995989 😰
# reward : -0.004019 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 163
# r      : 0.986600 😰
# reward : -0.013490 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 164
# r      : 1.018590 👍
# reward : 0.018419 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 165
# r      : 1.037442 👍
# reward : 0.036758 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 166
# r      : 1.049921 👍
# reward : 0.048715 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 167
# r      : 0.936380 😰
# reward : -0.065734 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 168
# r      : 0.936381 😰
# reward : -0.065732 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 169
# r      : 0.937746 😰
# reward : -0.064276 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 170
# r      : 0.997601 😰
# reward : -0.002402 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 171
# r      : 0.954711 😰
# reward : -0.046346 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 172
# r      : 0.997643 😰
# reward : -0.002360 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 173
# r      : 0.986354 😰
# reward : -0.013740 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 174
# r      : 1.003362 👍
# reward : 0.003356 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 175
# r      : 1.014307 👍
# reward : 0.014206 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 176
# r      : 0.997782 😰
# reward : -0.002221 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 177
# r      : 0.978677 😰
# reward : -0.021554 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 178
# r      : 1.007484 👍
# reward : 0.007456 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 179
# r      : 0.997767 😰
# reward : -0.002236 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 180
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 181
# r      : 0.965709 😰
# reward : -0.034892 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 182
# r      : 1.043722 👍
# reward : 0.042793 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 183
# r      : 0.997844 😰
# reward : -0.002158 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 184
# r      : 1.069839 👍
# reward : 0.067509 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 185
# r      : 1.075999 👍
# reward : 0.073249 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 186
# r      : 1.073440 👍
# reward : 0.070869 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 187
# r      : 0.997904 😰
# reward : -0.002098 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 188
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 189
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 190
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 191
# r      : 1.004511 👍
# reward : 0.004501 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 192
# r      : 0.997760 😰
# reward : -0.002242 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 193
# r      : 1.024707 👍
# reward : 0.024407 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 194
# r      : 1.026885 👍
# reward : 0.026530 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 195
# r      : 0.974911 😰
# reward : -0.025409 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 196
# r      : 0.997692 😰
# reward : -0.002311 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 197
# r      : 0.991861 😰
# reward : -0.008172 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 198
# r      : 1.016919 👍
# reward : 0.016778 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 199
# r      : 0.997787 😰
# reward : -0.002215 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 200
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 201
# r      : 1.050209 👍
# reward : 0.048990 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 202
# r      : 1.051339 👍
# reward : 0.050065 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 203
# r      : 0.997860 😰
# reward : -0.002142 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 204
# r      : 1.026220 👍
# reward : 0.025882 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 205
# r      : 1.008674 👍
# reward : 0.008636 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 206
# r      : 1.008586 👍
# reward : 0.008549 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 207
# r      : 0.997769 😰
# reward : -0.002233 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 208
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 209
# r      : 0.935897 😰
# reward : -0.066250 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 210
# r      : 0.934822 😰
# reward : -0.067400 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 211
# r      : 0.938999 😰
# reward : -0.062941 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 212
# r      : 1.045580 👍
# reward : 0.044572 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 213
# r      : 0.960100 😰
# reward : -0.040718 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 214
# r      : 0.997656 😰
# reward : -0.002346 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 215
# r      : 0.997008 😰
# reward : -0.002997 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 216
# r      : 0.980528 😰
# reward : -0.019664 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 217
# r      : 1.021921 👍
# reward : 0.021684 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 218
# r      : 0.962535 😰
# reward : -0.038185 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 219
# r      : 0.997662 😰
# reward : -0.002340 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 220
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 221
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 222
# r      : 0.998744 😰
# reward : -0.001257 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 223
# r      : 0.997747 😰
# reward : -0.002255 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 224
# r      : 0.963118 😰
# reward : -0.037579 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 225
# r      : 0.997664 😰
# reward : -0.002339 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 226
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 227
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 228
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 229
# r      : 1.036006 👍
# reward : 0.035373 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 230
# r      : 0.997828 😰
# reward : -0.002174 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 231
# r      : 1.006782 👍
# reward : 0.006759 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 232
# r      : 0.997765 😰
# reward : -0.002237 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 233
# r      : 1.015943 👍
# reward : 0.015817 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 234
# r      : 0.997785 😰
# reward : -0.002217 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 235
# r      : 1.027808 👍
# reward : 0.027428 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 236
# r      : 0.997811 😰
# reward : -0.002192 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 237
# r      : 1.017111 👍
# reward : 0.016967 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 238
# r      : 0.988847 😰
# reward : -0.011216 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 239
# r      : 1.008983 👍
# reward : 0.008943 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 240
# r      : 1.025164 👍
# reward : 0.024853 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 241
# r      : 0.997805 😰
# reward : -0.002197 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 242
# r      : 1.047195 👍
# reward : 0.046115 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 243
# r      : 0.997851 😰
# reward : -0.002151 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 244
# r      : 1.050642 👍
# reward : 0.049402 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 245
# r      : 0.949130 😰
# reward : -0.052209 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 246
# r      : 0.964270 😰
# reward : -0.036384 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 247
# r      : 0.977874 😰
# reward : -0.022374 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : None as step 248
# r      : 0.997699 😰
# reward : -0.002304 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Short as step 249
# r      : 1.003791 👍
# reward : 0.003784 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 250
# r      : 0.978246 😰
# reward : -0.021994 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.998.
#
# ACTION : Long as step 251
# r      : 0.975621 😰
# reward : -0.024681 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 252
# r      : 0.997694 😰
# reward : -0.002309 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 253
# r      : 1.020786 👍
# reward : 0.020573 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 254
# r      : 1.014744 👍
# reward : 0.014636 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 255
# r      : 1.002568 👍
# reward : 0.002564 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 256
# r      : 0.997756 😰
# reward : -0.002247 😰
#
# EPISODE DONE!
# —————————————————————————————————————————
# Episode 1 with cumulative reward -0.21585278136811778.
# 256 transitions in this episode.
# Total transitions: 256
#
# EPISODE: 2/500
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 1
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 2
# r      : 1.042354 👍
# reward : 0.041482 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 3
# r      : 0.948890 😰
# reward : -0.052463 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 4
# r      : 1.041071 👍
# reward : 0.040250 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 5
# r      : 1.041899 👍
# reward : 0.041045 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 6
# r      : 1.035560 👍
# reward : 0.034942 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 7
# r      : 1.027255 👍
# reward : 0.026890 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 8
# r      : 0.997810 😰
# reward : -0.002193 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 9
# r      : 1.006604 👍
# reward : 0.006582 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 10
# r      : 0.994323 😰
# reward : -0.005693 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 11
# r      : 0.990887 😰
# reward : -0.009155 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 12
# r      : 0.992590 😰
# reward : -0.007438 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 13
# r      : 0.992751 😰
# reward : -0.007275 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 14
# r      : 0.997734 😰
# reward : -0.002269 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 15
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 16
# r      : 0.991365 😰
# reward : -0.008673 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 17
# r      : 1.007558 👍
# reward : 0.007530 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 18
# r      : 0.978364 😰
# reward : -0.021873 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 19
# r      : 0.997700 😰
# reward : -0.002302 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 20
# r      : 1.018193 👍
# reward : 0.018029 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 21
# r      : 0.997790 😰
# reward : -0.002212 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 22
# r      : 1.010836 👍
# reward : 0.010777 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 23
# r      : 0.989387 😰
# reward : -0.010670 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 24
# r      : 1.002155 👍
# reward : 0.002153 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 25
# r      : 0.997755 😰
# reward : -0.002248 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 26
# r      : 0.979919 😰
# reward : -0.020286 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 27
# r      : 0.977206 😰
# reward : -0.023057 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 28
# r      : 0.975188 😰
# reward : -0.025125 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 29
# r      : 1.018879 👍
# reward : 0.018703 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 30
# r      : 0.975995 😰
# reward : -0.024298 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 31
# r      : 0.997695 😰
# reward : -0.002308 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 32
# r      : 0.992500 😰
# reward : -0.007528 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 33
# r      : 0.997733 😰
# reward : -0.002270 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 34
# r      : 0.986931 😰
# reward : -0.013155 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 35
# r      : 0.983254 😰
# reward : -0.016888 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 36
# r      : 0.979868 😰
# reward : -0.020337 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 37
# r      : 0.979519 😰
# reward : -0.020693 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 38
# r      : 1.012885 👍
# reward : 0.012803 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 39
# r      : 1.011761 👍
# reward : 0.011693 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 40
# r      : 0.997776 😰
# reward : -0.002226 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 41
# r      : 1.002136 👍
# reward : 0.002134 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 42
# r      : 1.012709 👍
# reward : 0.012629 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 43
# r      : 0.975867 😰
# reward : -0.024429 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 44
# r      : 1.019126 👍
# reward : 0.018945 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 45
# r      : 0.997792 😰
# reward : -0.002210 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 46
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 47
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 48
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 49
# r      : 0.995292 😰
# reward : -0.004719 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 50
# r      : 0.997739 😰
# reward : -0.002263 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 51
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 52
# r      : 1.015930 👍
# reward : 0.015805 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 53
# r      : 1.020512 👍
# reward : 0.020304 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 54
# r      : 1.019702 👍
# reward : 0.019510 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 55
# r      : 1.015788 👍
# reward : 0.015665 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 56
# r      : 0.997785 😰
# reward : -0.002217 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 57
# r      : 0.998882 😰
# reward : -0.001118 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 58
# r      : 1.002799 👍
# reward : 0.002795 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 59
# r      : 0.997756 😰
# reward : -0.002246 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 60
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 61
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 62
# r      : 0.974563 😰
# reward : -0.025766 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 63
# r      : 0.997691 😰
# reward : -0.002311 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 64
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 65
# r      : 0.992535 😰
# reward : -0.007493 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 66
# r      : 0.991893 😰
# reward : -0.008140 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 67
# r      : 0.997732 😰
# reward : -0.002271 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 68
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 69
# r      : 1.019155 👍
# reward : 0.018974 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 70
# r      : 0.973651 😰
# reward : -0.026702 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 71
# r      : 0.981341 😰
# reward : -0.018835 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 72
# r      : 0.987998 😰
# reward : -0.012074 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 73
# r      : 0.998009 😰
# reward : -0.001993 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 74
# r      : 0.991880 😰
# reward : -0.008153 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 75
# r      : 0.981228 😰
# reward : -0.018951 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 76
# r      : 1.023213 👍
# reward : 0.022948 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 77
# r      : 1.034254 👍
# reward : 0.033681 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 78
# r      : 0.957922 😰
# reward : -0.042989 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 79
# r      : 1.032419 👍
# reward : 0.031904 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 80
# r      : 0.997821 😰
# reward : -0.002182 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 81
# r      : 0.970606 😰
# reward : -0.029835 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 82
# r      : 1.014538 👍
# reward : 0.014434 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 83
# r      : 0.997782 😰
# reward : -0.002220 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 84
# r      : 1.001256 👍
# reward : 0.001255 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 85
# r      : 0.997992 😰
# reward : -0.002010 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 86
# r      : 1.000135 👍
# reward : 0.000135 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 87
# r      : 1.004316 👍
# reward : 0.004307 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 88
# r      : 1.000824 👍
# reward : 0.000824 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 89
# r      : 0.997752 😰
# reward : -0.002251 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Short as step 90
# r      : 0.984428 😰
# reward : -0.015694 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 91
# r      : 1.017147 👍
# reward : 0.017002 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 92
# r      : 0.997788 😰
# reward : -0.002215 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : None as step 93
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 94
# r      : 1.035853 👍
# reward : 0.035225 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.997.
#
# ACTION : Long as step 95
# r      : 1.037501 👍
# reward : 0.036815 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : None as step 96
# r      : 0.997831 😰
# reward : -0.002171 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : Short as step 97
# r      : 0.970638 😰
# reward : -0.029801 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : Short as step 98
# r      : 0.981659 😰
# reward : -0.018512 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : Long as step 99
# r      : 1.003683 👍
# reward : 0.003676 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : Long as step 100
# r      : 0.998476 😰
# reward : -0.001525 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : None as step 101
# r      : 0.997747 😰
# reward : -0.002256 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : None as step 102
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.996.
#
# ACTION : Long as step 103
# r      : 0.978142 😰
# reward : -0.022100 😰
# ...
# CURRENT EPSILON: 0.987.
#
# ACTION : None as step 75
# r      : 0.997740 😰
# reward : -0.002262 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.987.
#
# ACTION : Short as step 76
# r      : 0.991693 😰
# reward : -0.008341 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.987.
#
# ACTION : None as step 77
# r      : 0.997731 😰
# reward : -0.002271 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.987.
#
# ACTION : None as step 78
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.987.
#
# ACTION : Long as step 79
# r      : 1.014465 👍
# reward : 0.014361 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.987.
#
# ACTION : Long as step 80
# r      : 1.017995 👍
# reward : 0.017835 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 81
# r      : 0.977530 😰
# reward : -0.022726 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 82
# r      : 1.011655 👍
# reward : 0.011587 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 83
# r      : 1.013456 👍
# reward : 0.013367 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 84
# r      : 0.997780 😰
# reward : -0.002223 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 85
# r      : 0.990986 😰
# reward : -0.009055 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 86
# r      : 0.996332 😰
# reward : -0.003675 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 87
# r      : 0.998579 😰
# reward : -0.001422 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 88
# r      : 0.997747 😰
# reward : -0.002256 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 89
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 90
# r      : 0.995057 😰
# reward : -0.004955 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 91
# r      : 1.001032 👍
# reward : 0.001031 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 92
# r      : 1.009375 👍
# reward : 0.009332 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 93
# r      : 0.997771 😰
# reward : -0.002232 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 94
# r      : 0.980251 😰
# reward : -0.019946 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 95
# r      : 0.997705 😰
# reward : -0.002298 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 96
# r      : 0.975453 😰
# reward : -0.024853 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 97
# r      : 0.977303 😰
# reward : -0.022959 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 98
# r      : 0.978436 😰
# reward : -0.021800 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 99
# r      : 0.997700 😰
# reward : -0.002302 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 100
# r      : 0.982070 😰
# reward : -0.018093 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 101
# r      : 1.007023 👍
# reward : 0.006998 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 102
# r      : 1.007584 👍
# reward : 0.007555 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 103
# r      : 0.997767 😰
# reward : -0.002236 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 104
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 105
# r      : 0.997637 😰
# reward : -0.002365 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 106
# r      : 0.999621 😰
# reward : -0.000379 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 107
# r      : 0.997749 😰
# reward : -0.002253 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 108
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 109
# r      : 0.992480 😰
# reward : -0.007548 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 110
# r      : 1.003290 👍
# reward : 0.003285 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 111
# r      : 0.985104 😰
# reward : -0.015008 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 112
# r      : 0.987897 😰
# reward : -0.012177 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 113
# r      : 0.987289 😰
# reward : -0.012793 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 114
# r      : 1.007378 👍
# reward : 0.007351 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 115
# r      : 1.010125 👍
# reward : 0.010074 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 116
# r      : 1.007365 👍
# reward : 0.007338 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 117
# r      : 0.997766 😰
# reward : -0.002236 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 118
# r      : 0.997254 😰
# reward : -0.002749 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 119
# r      : 1.002970 👍
# reward : 0.002966 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 120
# r      : 0.989482 😰
# reward : -0.010573 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 121
# r      : 0.997726 😰
# reward : -0.002277 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 122
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 123
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 124
# r      : 1.004167 👍
# reward : 0.004158 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 125
# r      : 1.003962 👍
# reward : 0.003954 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 126
# r      : 1.001055 👍
# reward : 0.001055 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 127
# r      : 0.997165 😰
# reward : -0.002839 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 128
# r      : 0.997744 😰
# reward : -0.002259 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 129
# r      : 1.003520 👍
# reward : 0.003513 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 130
# r      : 0.997758 😰
# reward : -0.002245 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 131
# r      : 1.003448 👍
# reward : 0.003442 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 132
# r      : 1.003956 👍
# reward : 0.003948 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 133
# r      : 0.997759 😰
# reward : -0.002244 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 134
# r      : 0.999367 😰
# reward : -0.000633 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 135
# r      : 0.997749 😰
# reward : -0.002254 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 136
# r      : 0.989689 😰
# reward : -0.010364 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 137
# r      : 0.997727 😰
# reward : -0.002276 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 138
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 139
# r      : 1.009390 👍
# reward : 0.009346 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 140
# r      : 0.997771 😰
# reward : -0.002232 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 141
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 142
# r      : 0.991605 😰
# reward : -0.008430 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 143
# r      : 0.998421 😰
# reward : -0.001580 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 144
# r      : 1.000042 👍
# reward : 0.000042 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 145
# r      : 0.997683 😰
# reward : -0.002320 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 146
# r      : 0.996171 😰
# reward : -0.003836 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 147
# r      : 0.995707 😰
# reward : -0.004303 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 148
# r      : 0.998975 😰
# reward : -0.001026 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 149
# r      : 0.993383 😰
# reward : -0.006639 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 150
# r      : 0.997735 😰
# reward : -0.002268 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 151
# r      : 0.994891 😰
# reward : -0.005123 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 152
# r      : 0.997738 😰
# reward : -0.002264 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 153
# r      : 1.004868 👍
# reward : 0.004856 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 154
# r      : 0.997761 😰
# reward : -0.002242 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 155
# r      : 0.989140 😰
# reward : -0.010920 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 156
# r      : 0.992339 😰
# reward : -0.007691 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 157
# r      : 0.994348 😰
# reward : -0.005668 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 158
# r      : 0.997737 😰
# reward : -0.002265 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 159
# r      : 0.998143 😰
# reward : -0.001858 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 160
# r      : 0.997746 😰
# reward : -0.002257 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 161
# r      : 0.991101 😰
# reward : -0.008939 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 162
# r      : 0.997730 😰
# reward : -0.002273 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : None as step 163
# r      : 1.000000 👍
# reward : 0.000000 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 164
# r      : 0.988287 😰
# reward : -0.011782 😰
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Long as step 165
# r      : 1.003443 👍
# reward : 0.003437 👍
# —————————————————————————————————————————
# CURRENT EPSILON: 0.986.
#
# ACTION : Short as step 166
# r      : 0.989574 😰
# reward : -0.010480 😰
# —————————————————————————————————————————
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3778/208529851.py in <module>
# ----> 1 rewards, cum_rewards = agent.train(500)
#
# ~/code/cryptobot/name_me/reinforcement_learning/agents.py in train(self, num_episodes)
#      81             while not done:
#      82                 # get action according to exploration process
# ---> 83                 action = self.get_action(state)
#      84
#      85                 # apply action to environment
#
# ~/code/cryptobot/name_me/reinforcement_learning/agents.py in get_action(self, observation)
#      55         with torch.no_grad():
#      56             # unsqueeze: batch size = 1
# ---> 57             Qvals = self.Q(observation.unsqueeze(0))
#      58         self.Q.train()
#      59
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/code/cryptobot/name_me/reinforcement_learning/q_funcs.py in forward(self, state)
#     135
#     136     def forward(self, state: Tensor) -> Tensor:
# --> 137         return self.online_Q(state)
#     138
#     139     def train(self) -> None:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/code/cryptobot/name_me/reinforcement_learning/q_funcs.py in forward(self, states)
#      80
#      81         # pass data through convolutional part
# ---> 82         features = self.conv(states)
#      83
#      84         # flatten features for perceptron pass
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     393                             weight, bias, self.stride,
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#     397
#
# KeyboardInterrupt:
